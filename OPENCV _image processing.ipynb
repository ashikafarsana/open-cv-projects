# %%
import cv2

# %%
img=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")

# %%
cv2.imshow("mohanlal",img)
k=cv2.waitKey()
if k==27:
    cv2.destroyAllWindows()
elif k==ord('s'):
    cv2.imwrite("C:/Users/PARCHU/ashika",img)
    cv2.destroyAllWindows()

# %%
import cv2
img=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
imgGray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow("gray image",imgGray)
k=cv2.waitKey()
if k==27:
    cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
cv2.imshow("mohanlal",img)
k=cv2.waitKey()
if k==27:
    cv2.destroyAllWindows()
plt.imshow(img)
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img2)
plt.title("MOHANLAL")
# Out:
# Text(0.5, 1.0, 'MOHANLAL')

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.xticks([]), plt.yticks([])
plt.imshow(img2)
plt.title("MOHANLAL")
# Out:
# Text(0.5, 1.0, 'MOHANLAL')

# %%
import cv2
a=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
cv2.imshow("image",a)
cv2.waitKey()
cv2.destroyAllWindows()
print(type(a))
print(a.shape)
print(a.dtype)
print(a.min())
print(a.max())
print(a.size)
# Out:
# <class 'numpy.ndarray'>
# (900, 1200, 3)
# uint8
# 0
# 255
# 3240000

# %%
import cv2
from matplotlib import pyplot as plt
a=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
cv2.imshow("image",a)
cv2.waitKey()
cv2.destroyAllWindows()
b=cv2.imread("C:/Users/PARCHU/Desktop/opencv/flower.jpg")
cv2.imshow("image",b)
cv2.waitKey()
cv2.destroyAllWindows()
a=cv2.resize(a,(300,300))
b=cv2.resize(b,(300,300))
blend=cv2.addWeighted(a,0.8,b,0.5,0)
plt.xticks([]), plt.yticks([])
plt.imshow(blend[...,::-1])

# %%
import cv2
img=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
imgcanny=cv2.Canny(img,150,200)
cv2.imshow("canny show",imgcanny)
k=cv2.waitKey()
if k==27:
0    cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
img=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
width,height=250,300
point1 = np.float32([[111, 400], [200, 200], [230, 482], [230, 440]])
point2 = np.float32([[0, 0], [width, 0], [0, height], [width, height]])
matrix = cv2.getPerspectiveTransform(point1, point2)
Output = cv2.warpPerspective(img, matrix, (width, height))
cv2.imshow("image",img)
cv2.imshow("output",Output)
k=cv2.waitKey()
if k==27:
    cv2.destroyAllWindows()

# %%
import cv2
img=cv2.imread("C:/Users/PARCHU/Desktop/opencv/mohanlal.jpg")
print("original dimensions:",img.shape)
scale=60
width=int(img.shape[1] * scale / 100)
height=int(img.shape[0] * scale / 100)  
dim=(width,height)
resized = cv2.resize(img, dim, interpolation=cv2.INTER_AREA)  
print("resized dimension:",resized.shape)
cv2.imshow("resized image",resized)
k=cv2.waitKey()
if k==27:
    cv2.destroyAllWindows()
# Out:
# original dimensions: (900, 1200, 3)
# resized dimension: (540, 720, 3)
